# %% [markdown]
# # Ensemble

# %% [markdown]
# ## Simple Ensemble Techniques
#
# Max Voting
#
# Averaging
#
# Weighted Averaging

# %% [markdown]
# 1. Max vote - say 6 model has been created, get the max vote for the calssified output and select it
# 2. Average - take the average of all the six model and select the output. it works for regression,
# but using probability it can be used for classification as well.
# 3. Weighted average - similar to average, but weightage is given here. out of 5 friends if 2 of them are critic and
# they have prior exp then weight for their comments is given more. same way weight for well trained model is given

# %% [markdown]
# #  Advanced Ensemble techniques
#
# 1. Stacking
#
# 2. Blending
#
# 3. Bagging
#
# 4. Boosting

# %% [markdown]
# ## Stacking

# %% [markdown]
# 1. Split the train dataset into 10 part.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. Build themodel DT with 9  parts and test it with the 10th part of the train dataset

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 3. The base model (DT) is then fitted on the whole train dataset.

# %% [markdown]
# 4. Using 3rd step model, do the prediction with the test dataset

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. Steps 2 to 4 are repeated for another base model (say knn) resulting in another set of predictions for the train set and test set.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 6. The predictions from the train set are used as features to build a new model

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 7. This model is used to make final predictions on the test prediction set.

# %% [markdown]
# ## Blending

# %% [markdown]
# Blending follows the same approach as stacking but uses only a holdout (validation) set from the train set to make predictions. In other words, unlike stacking, the predictions are made on the holdout set only.

# %% [markdown]
# 1. The train set is split into training and validation sets

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2.Model(s) are fitted on the training set.
#
# 3.The predictions are made on the validation set and the test set

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4.The validation set and its predictions are used as features to build a new model.
#
# 5.This model is used to make final predictions on the test and meta-features.

# %% [markdown]
# ## Bagging

# %% [markdown]
# Bootstrapping is a sampling technique in which we create subsets of observations from the original dataset, with replacement. The size of the subsets is the same as the size of the original set.
#
# Bagging (or Bootstrap Aggregating) technique uses these subsets (bags) to get a fair idea of the distribution (complete set). The size of subsets created for bagging may be less than the original set.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1.Multiple subsets are created from the original dataset, selecting observations with replacement.
#
# 2.A base model (weak model) is created on each of these subsets.
#
# 3.The models run in parallel and are independent of each other.
#
# 4.The final predictions are determined by combining the predictions from all the models

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Bagging meta-estimator
# Random forest

# %% [markdown]
# ## Bossting

# %% [markdown]
# Boosting is a sequential process, where each subsequent model attempts to correct the errors of the previous model. The succeeding models are dependent on the previous model. Let’s understand the way boosting works in the below steps.
#
# A subset is created from the original dataset.
#
# Initially, all data points are given equal weights.
#
# A base model is created on this subset.
#
# This model is used to make predictions on the whole dataset

# %% [markdown]
# Errors are calculated using the actual values and predicted values.
#
# The observations which are incorrectly predicted, are given higher weights.
#
# (Here, the three misclassified blue-plus points will be given higher weights)
#
# Another model is created and predictions are made on the dataset.
# (This model tries to correct the errors from the previous model)

# %% [markdown]
# Similarly, multiple models are created, each correcting the errors of the previous model.
#
# The final model (strong learner) is the weighted mean of all the models (weak learners)

# %% [markdown]
# Thus, the boosting algorithm combines a number of weak learners to form a strong learner. The individual models would not perform well on the entire dataset, but they work well for some part of the dataset. Thus, each model actually boosts the performance of the ensemble.

# %% [markdown]
# Boosting algorithms:
#
# AdaBoost
#
# GBM
#
# XGBM
#
# Light GBM
#
# CatBoost
