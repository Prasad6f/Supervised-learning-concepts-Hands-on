# %% [markdown]
# # Decision Tree using Iris dataset

# %% [markdown]
# #### Import libraries

# %%
import sklearn.datasets as datasets
import pandas as pd

# %% [markdown]
# #### load the input dataset

# %%
iris=datasets.load_iris()
df=pd.DataFrame(iris.data, columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
# target variable
y=iris.target
y = pd.DataFrame(y)
y.head()
# Out:
#    0
# 0  0
# 1  0
# 2  0
# 3  0
# 4  0

# %% [markdown]
# #### Build Randomforest Classification model

# %%
from sklearn.tree import DecisionTreeClassifier

dtree=DecisionTreeClassifier()
dtree.fit(df,y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
# !pip install graphviz
# !pip install pydot
# Out:
# Requirement already satisfied: graphviz in c:\users\user\anaconda3\lib\site-packages (0.13)
# Requirement already satisfied: pydot in c:\users\user\anaconda3\lib\site-packages (1.4.1)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\user\anaconda3\lib\site-packages (from pydot) (2.3.1)

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz

import pydotplus
import pydot
from IPython.display import Image

from IPython import display
from sklearn import datasets, utils, tree
from sklearn.externals.six import StringIO

# %%
dot_data = StringIO()

# %%
export_graphviz(dtree, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True)

# %%
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())
# Out:
# Warning: Could not load "C:\Users\user\Anaconda3\Library\bin\gvplugin_pango.dll" - can't open the module
# Warning: Could not load "C:\Users\user\Anaconda3\Library\bin\gvplugin_pango.dll" - can't open the module
# Warning: Could not load "C:\Users\user\Anaconda3\Library\bin\gvplugin_pango.dll" - can't open the module
# Warning: Could not load "C:\Users\user\Anaconda3\Library\bin\gvplugin_pango.dll" - can't open the module
# Warning: Could not load "C:\Users\user\Anaconda3\Library\bin\gvplugin_pango.dll" - can't open the module
